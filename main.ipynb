# %%
import pandas as pd
import torch
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-53-18e7fcb20c7f> in <module>
#       1 import pandas as pd
# ----> 2 import torch
#
# ~\miniconda3\envs\torch\lib\site-packages\torch\__init__.py in <module>
#      79     dlls = glob.glob(os.path.join(th_dll_path, '*.dll'))
#      80     for dll in dlls:
# ---> 81         ctypes.CDLL(dll)
#      82
#      83
#
# ~\miniconda3\envs\torch\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     362
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#     366             self._handle = handle
#
# OSError: [WinError 126] The specified module could not be found

# %%
REAL = 'genuine_bin'
FORGED = 'forged_bin'

# %%
true = pd.read_csv('true_signatures.csv')
forged = pd.read_csv('forged_signatures.csv')

# %%
true.drop(true.columns[[0]], axis=1, inplace=True)
forged.drop(forged.columns[[0]], axis=1, inplace=True)

# %%
forged.columns = ['owner',	'fake', 'original', 'fake_img', 'original_img', 'target']
forged
# Out:
#      owner  fake  original          fake_img      original_img  target
# 0       14     1         1  NFI-00101014.png  NFI-01401014.png       0
# 1       14     1         2  NFI-00101014.png  NFI-01402014.png       0
# 2       14     1         3  NFI-00101014.png  NFI-01403014.png       0
# 3       14     1         4  NFI-00101014.png  NFI-01404014.png       0
# 4       14     1         5  NFI-00101014.png  NFI-01405014.png       0
# ..     ...   ...       ...               ...               ...     ...
# 745      4     5         1  NFI-08805004.png  NFI-00401004.png       0
# 746      4     5         2  NFI-08805004.png  NFI-00402004.png       0
# 747      4     5         3  NFI-08805004.png  NFI-00403004.png       0
# 748      4     5         4  NFI-08805004.png  NFI-00404004.png       0
# 749      4     5         5  NFI-08805004.png  NFI-00405004.png       0
#
# [750 rows x 6 columns]

# %%
real
# Out:
#      owner  sig1  sig2          sig1_img          sig2_img  target
# 0        1     1     2  NFI-00101001.png  NFI-00102001.png       1
# 1        1     1     3  NFI-00101001.png  NFI-00103001.png       1
# 2        1     1     4  NFI-00101001.png  NFI-00104001.png       1
# 3        1     1     5  NFI-00101001.png  NFI-00105001.png       1
# 4        1     2     3  NFI-00102001.png  NFI-00103001.png       1
# ..     ...   ...   ...               ...               ...     ...
# 295     30     2     4  NFI-03002030.PNG  NFI-03004030.PNG       1
# 296     30     2     5  NFI-03002030.PNG  NFI-03005030.PNG       1
# 297     30     3     4  NFI-03003030.PNG  NFI-03004030.PNG       1
# 298     30     3     5  NFI-03003030.PNG  NFI-03005030.PNG       1
# 299     30     4     5  NFI-03004030.PNG  NFI-03005030.PNG       1
#
# [300 rows x 6 columns]

# %%
forged = forged.groupby(['owner','fake']).head(3).reset_index(drop=True)

# %%
forged['fake_img'] = forged['fake_img'].apply(lambda x: FORGED+'/'+x)
forged['original_img'] = forged['original_img'].apply(lambda x: REAL+'/'+x)
forged
# Out:
#      owner  fake  original                     fake_img  \
# 0       14     1         1  forged_bin/NFI-00101014.png
# 1       14     1         2  forged_bin/NFI-00101014.png
# 2       14     1         3  forged_bin/NFI-00101014.png
# 3       14     2         1  forged_bin/NFI-00102014.png
# 4       14     2         2  forged_bin/NFI-00102014.png
# ..     ...   ...       ...                          ...
# 442      4     4         2  forged_bin/NFI-08804004.png
# 443      4     4         3  forged_bin/NFI-08804004.png
# 444      4     5         1  forged_bin/NFI-08805004.png
# 445      4     5         2  forged_bin/NFI-08805004.png
# 446      4     5         3  forged_bin/NFI-08805004.png
#
#                      original_img  target
# 0    genuine_bin/NFI-01401014.png       0
# 1    genuine_bin/NFI-01402014.png       0
# 2    genuine_bin/NFI-01403014.png       0
# 3    genuine_bin/NFI-01401014.png       0
# 4    genuine_bin/NFI-01402014.png       0
# ..                            ...     ...
# 442  genuine_bin/NFI-00402004.png       0
# 443  genuine_bin/NFI-00403004.png       0
# 444  genuine_bin/NFI-00401004.png       0
# 445  genuine_bin/NFI-00402004.png       0
# 446  genuine_bin/NFI-00403004.png       0
#
# [447 rows x 6 columns]

# %%
forged['fake_img'] = forged['fake_img'].apply(lambda x: FORGED+'/'+x)
forged['original_img'] = forged['original_img'].apply(lambda x: REAL+'/'+x)
forged

# %%
real['sig1_img'] = real['sig1_img'].apply(lambda x: REAL+'/'+x)
real['sig2_img'] = real['sig2_img'].apply(lambda x: REAL+'/'+x)
real
# Out:
#      owner  sig1  sig2                      sig1_img  \
# 0        1     1     2  genuine_bin/NFI-00101001.png
# 1        1     1     3  genuine_bin/NFI-00101001.png
# 2        1     1     4  genuine_bin/NFI-00101001.png
# 3        1     1     5  genuine_bin/NFI-00101001.png
# 4        1     2     3  genuine_bin/NFI-00102001.png
# ..     ...   ...   ...                           ...
# 295     30     2     4  genuine_bin/NFI-03002030.PNG
# 296     30     2     5  genuine_bin/NFI-03002030.PNG
# 297     30     3     4  genuine_bin/NFI-03003030.PNG
# 298     30     3     5  genuine_bin/NFI-03003030.PNG
# 299     30     4     5  genuine_bin/NFI-03004030.PNG
#
#                          sig2_img  target
# 0    genuine_bin/NFI-00102001.png       1
# 1    genuine_bin/NFI-00103001.png       1
# 2    genuine_bin/NFI-00104001.png       1
# 3    genuine_bin/NFI-00105001.png       1
# 4    genuine_bin/NFI-00103001.png       1
# ..                            ...     ...
# 295  genuine_bin/NFI-03004030.PNG       1
# 296  genuine_bin/NFI-03005030.PNG       1
# 297  genuine_bin/NFI-03004030.PNG       1
# 298  genuine_bin/NFI-03005030.PNG       1
# 299  genuine_bin/NFI-03005030.PNG       1
#
# [300 rows x 6 columns]

# %%
df1 = forged[['owner','fake_img', 'original_img','target']]
df2 = real[['owner','sig1_img', 'sig2_img','target']]

# %%
cols = ['owner','img1', 'img2','target']
df1.columns = cols
df2.columns = cols

# %%
 dataset = pd.concat([df1, df2])

# %%
dataset.to_csv('train.csv')

# %%
dataset = dataset.sample(frac=1).reset_index(drop=True)
dataset
# Out:
#      owner                          img1                          img2  target
# 0        3  genuine_bin/NFI-00304003.png  genuine_bin/NFI-00305003.png       1
# 1       27   forged_bin/NFI-00101027.PNG  genuine_bin/NFI-02702027.PNG       0
# 2       27   forged_bin/NFI-00104027.PNG  genuine_bin/NFI-02703027.PNG       0
# 3       26  genuine_bin/NFI-02601026.PNG  genuine_bin/NFI-02604026.PNG       1
# 4        1   forged_bin/NFI-00302001.png  genuine_bin/NFI-00101001.png       0
# ..     ...                           ...                           ...     ...
# 742     11   forged_bin/NFI-00704011.png  genuine_bin/NFI-01101011.png       0
# 743     26   forged_bin/NFI-00105026.PNG  genuine_bin/NFI-02603026.PNG       0
# 744      3   forged_bin/NFI-00404003.png  genuine_bin/NFI-00303003.png       0
# 745      4   forged_bin/NFI-08802004.png  genuine_bin/NFI-00402004.png       0
# 746     29   forged_bin/NFI-00104029.PNG  genuine_bin/NFI-02902029.PNG       0
#
# [747 rows x 4 columns]

# %%
# dataset['target'] = dataset['target'].astype('int16')
dataset
# Out:
#      owner                          img1                          img2  target
# 0        3  genuine_bin/NFI-00304003.png  genuine_bin/NFI-00305003.png       1
# 1       27   forged_bin/NFI-00101027.PNG  genuine_bin/NFI-02702027.PNG       0
# 2       27   forged_bin/NFI-00104027.PNG  genuine_bin/NFI-02703027.PNG       0
# 3       26  genuine_bin/NFI-02601026.PNG  genuine_bin/NFI-02604026.PNG       1
# 4        1   forged_bin/NFI-00302001.png  genuine_bin/NFI-00101001.png       0
# ..     ...                           ...                           ...     ...
# 742     11   forged_bin/NFI-00704011.png  genuine_bin/NFI-01101011.png       0
# 743     26   forged_bin/NFI-00105026.PNG  genuine_bin/NFI-02603026.PNG       0
# 744      3   forged_bin/NFI-00404003.png  genuine_bin/NFI-00303003.png       0
# 745      4   forged_bin/NFI-08802004.png  genuine_bin/NFI-00402004.png       0
# 746     29   forged_bin/NFI-00104029.PNG  genuine_bin/NFI-02902029.PNG       0
#
# [747 rows x 4 columns]

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        row = self.dataframe.iloc[index]
        img1 = torchvision.transforms.functional.to_tensor(Image.open(row["img1"])).convert('L')
        img2 = torchvision.transforms.functional.to_tensor(Image.open(row["img2"])).convert('L')
        target = row["target"]
        
        return (img1, img2, target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-8429d42dd855> in <module>
# ----> 1 class Dataset(torch.utils.data.Dataset):
#       2     def __init__(self, dataframe):
#       3         self.dataframe = dataframe
#       4
#       5     def __len__(self):
#
# NameError: name 'torch' is not defined
